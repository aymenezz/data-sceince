# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline 
sns.set()
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# - Column	Description
# - CensusTract	رقم منطقة التعداد (وحدة جغرافية صغيرة تُستخدم في الإحصاء)
# - State	اسم الولاية
# - County	اسم المقاطعة
# - TotalPop	إجمالي عدد السكان
# - Men	عدد الذكور
# - Women	عدد الإناث
# - Hispanic	نسبة السكان من أصل إسباني (%)
# - White	نسبة السكان البيض (%)
# - Black	نسبة السكان السود أو الأفارقة الأمريكيين (%)
# - Native	نسبة السكان من السكان الأصليين الأمريكيين (%)
# - Asian	نسبة السكان الآسيويين (%)
# - Pacific	نسبة سكان جزر المحيط الهادئ (%)
# - Citizen	عدد المواطنين الأمريكيين في المنطقة
# - Income	متوسط دخل الأسرة
# - IncomeErr	هامش الخطأ في تقدير متوسط الدخل
# - IncomePerCap	متوسط دخل الفرد
# - IncomePerCapErr	هامش الخطأ في تقدير دخل الفرد
# - Poverty	نسبة السكان تحت خط الفقر (%)
# - ChildPoverty	نسبة الأطفال تحت خط الفقر (%)
# - Professional	نسبة العاملين في وظائف احترافية (%)
# - Service	نسبة العاملين في الخدمات (%)
# - Office	نسبة العاملين في المكاتب (%)
# - Construction	نسبة العاملين في البناء (%)
# - Production	نسبة العاملين في الإنتاج والمصانع (%)
# - Drive	نسبة الذين يقودون سياراتهم بأنفسهم للعمل (%)
# - Carpool	نسبة الذين يذهبون للعمل مع آخرين بالسيارة (%)
# - Transit	نسبة الذين يستخدمون المواصلات العامة (%)
# - Walk	نسبة الذين يمشون إلى العمل (%)
# - OtherTransp	نسبة الذين يستخدمون وسائل أخرى للعمل (%)
# - WorkAtHome	نسبة الذين يعملون من المنزل (%)
# - MeanCommute	متوسط وقت التنقل للعمل (بالدقائق)
# - Employed	عدد العاملين
# - PrivateWork	نسبة العاملين في القطاع الخاص (%)
# - PublicWork	نسبة العاملين في القطاع العام (%)
# - SelfEmployed	نسبة العاملين لحسابهم الخاص (%)
# - FamilyWork	نسبة العاملين في أعمال أسرية بدون أجر (%)
# - Unemployment	نسبة البطالة (%)

# %%
df=pd.read_csv('./acs2015_census_tract_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74001 entries, 0 to 74000
# Data columns (total 37 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CensusTract      74001 non-null  int64
#  1   State            74001 non-null  object
#  2   County           74001 non-null  object
#  3   TotalPop         74001 non-null  int64
#  4   Men              74001 non-null  int64
#  5   Women            74001 non-null  int64
#  6   Hispanic         73311 non-null  float64
#  7   White            73311 non-null  float64
#  8   Black            73311 non-null  float64
#  9   Native           73311 non-null  float64
#  10  Asian            73311 non-null  float64
#  11  Pacific          73311 non-null  float64
#  12  Citizen          74001 non-null  int64
#  13  Income           72901 non-null  float64
#  14  IncomeErr        72901 non-null  float64
#  15  IncomePerCap     73261 non-null  float64
#  16  IncomePerCapErr  73261 non-null  float64
#  17  Poverty          73166 non-null  float64
#  18  ChildPoverty     72883 non-null  float64
#  19  Professional     73194 non-null  float64
#  20  Service          73194 non-null  float64
#  21  Office           73194 non-null  float64
#  22  Construction     73194 non-null  float64
#  23  Production       73194 non-null  float64
#  24  Drive            73204 non-null  float64
#  25  Carpool          73204 non-null  float64
#  26  Transit          73204 non-null  float64
#  27  Walk             73204 non-null  float64
#  28  OtherTransp      73204 non-null  float64
#  29  WorkAtHome       73204 non-null  float64
#  30  MeanCommute      73052 non-null  float64
#  31  Employed         74001 non-null  int64
#  32  PrivateWork      73194 non-null  float64
#  33  PublicWork       73194 non-null  float64
#  34  SelfEmployed     73194 non-null  float64
#  35  FamilyWork       73194 non-null  float64
#  36  Unemployment     73199 non-null  float64
# dtypes: float64(29), int64(6), object(2)
# memory usage: 20.9+ MB

# %%
df.isna().sum()
# Out:
# CensusTract           0
# State                 0
# County                0
# TotalPop              0
# Men                   0
# Women                 0
# Hispanic            690
# White               690
# Black               690
# Native              690
# Asian               690
# Pacific             690
# Citizen               0
# Income             1100
# IncomeErr          1100
# IncomePerCap        740
# IncomePerCapErr     740
# Poverty             835
# ChildPoverty       1118
# Professional        807
# Service             807
# Office              807
# Construction        807
# Production          807
# Drive               797
# Carpool             797
# Transit             797
# Walk                797
# OtherTransp         797
# WorkAtHome          797
# MeanCommute         949
# Employed              0
# PrivateWork         807
# PublicWork          807
# SelfEmployed        807
# FamilyWork          807
# Unemployment        802
# dtype: int64

# %%
df['White'].mean()
# Out:
# 62.03210568673188

# %%
number_type=df.select_dtypes(include='number').columns[0:]
mean_number_values=df[number_type].mean()
df[number_type]=df[number_type].fillna(mean_number_values)

# %%
# df.isna().sum()

# %%
df.head()
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008      0.90  87.40
# 1   1001020200  Alabama  Autauga      2156  1059   1097      0.80  40.40
# 2   1001020300  Alabama  Autauga      2968  1364   1604      0.00  74.50
# 3   1001020400  Alabama  Autauga      4423  2172   2251     10.50  82.80
# 4   1001020500  Alabama  Autauga     10763  4922   5841      0.70  68.50
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0   7.70    0.30  ...  0.50         2.30        2.10        25.00       943
# 1  53.30    0.00  ...  0.00         0.70        0.00        23.40       753
# 2  18.60    0.50  ...  0.00         0.00        2.50        19.60      1373
# 3   3.70    1.60  ...  0.00         2.60        1.60        25.30      1782
# 4  24.80    0.00  ...  0.00         0.60        0.90        24.80      5037
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0        77.10       18.30          4.60        0.00          5.40
# 1        77.00       16.90          6.10        0.00         13.30
# 2        64.10       23.60         12.30        0.00          6.20
# 3        75.70       21.20          3.10        0.00         10.80
# 4        67.10       27.60          5.30        0.00          4.20
#
# [5 rows x 37 columns]

# %%
sort_state_papuler=df.groupby(['State'])[['Hispanic','White','Black','Native',]].sum().sort_values(by='White',ascending=False).reset_index().head(10)
sort_state_papuler
# Out:
#             State  Hispanic     White    Black  Native
# 0      California 299541.33 325000.34 46084.57 3279.95
# 1        New York  84770.23 278059.26 76909.33 1606.59
# 2         Florida  90255.39 251025.74 64240.10  931.12
# 3    Pennsylvania  19891.70 248775.61 37464.26  393.54
# 4           Texas 199511.09 235940.92 61399.16 1392.65
# 5            Ohio  10985.09 223913.25 47811.60  504.70
# 6        Michigan  13784.13 202978.46 49335.93 1377.49
# 7        Illinois  48734.30 190074.56 53398.88  374.72
# 8  North Carolina  18781.71 141730.27 46767.34 2374.07
# 9        Virginia  15524.86 120623.20 38282.33  419.58

# %%
sort_state_papuler.plot.barh(x='State',stacked=True)
plt.show()

# %%
sort_state_papuler.plot.barh(x='State')
plt.show()

# %%
df['IncomeQuantile']=pd.qcut(df['Income'],q=5,labels=['Q1','Q2','Q3','Q4','Q5'])

# %% [markdown]
# # 1. How many different states are in the data?

# %%
df['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %%
df['State'].nunique()
# Out:
# 52

# %% [markdown]
# # 2. Which county has the largest population?

# %%
df.groupby('County')['TotalPop'].sum().sort_values(ascending=False).head(10)
# Out:
# County
# Los Angeles    10038388
# Cook            5258620
# Orange          5025603
# Harris          4389138
# Maricopa        4018143
# Montgomery      3635047
# Jefferson       3623682
# San Diego       3223096
# Clark           2852761
# Kings           2746257
# Name: TotalPop, dtype: int64

# %% [markdown]
# # 3-Which Census Tract has the highest percentage of white residents?

# %%
df.groupby(['CensusTract'])['White'].sum().head(10)
# Out:
# CensusTract
# 1001020100   87.40
# 1001020200   40.40
# 1001020300   74.50
# 1001020400   82.80
# 1001020500   68.50
# 1001020600   72.90
# 1001020700   74.50
# 1001020801   84.00
# 1001020802   89.50
# 1001020900   85.50
# Name: White, dtype: float64

# %% [markdown]
# # 4-What is the average number of males and females in the census areas?

# %%
df.groupby('State')[['Men','Women']].mean()
# Out:
#                          Men   Women
# State
# Alabama              1982.30 2107.98
# Alaska               2300.36 2091.11
# Arizona              2161.92 2190.59
# Arkansas             2116.49 2195.77
# California           2369.01 2399.69
# Colorado             2120.63 2105.88
# Connecticut          2102.77 2210.82
# Delaware             2056.94 2192.85
# District of Columbia 1713.26 1903.97
# Florida              2261.49 2366.49
# Georgia              2480.11 2602.01
# Hawaii               2022.42 1984.13
# Idaho                2719.68 2704.98
# Illinois             2022.70 2099.54
# Indiana              2141.14 2206.08
# Iowa                 1860.12 1889.61
# Kansas               1869.95 1887.18
# Kentucky             1940.99 2002.82
# Louisiana            1969.65 2059.32
# Maine                1815.87 1896.70
# Maryland             2043.13 2174.89
# Massachusetts        2198.68 2338.25
# Michigan             1728.39 1791.18
# Minnesota            2012.08 2038.12
# Mississippi          2186.33 2313.79
# Missouri             2127.78 2212.09
# Montana              1882.52 1861.76
# Nebraska             1747.38 1766.46
# Nevada               2049.10 2024.60
# New Hampshire        2215.20 2273.62
# New Jersey           2160.71 2269.35
# New Mexico           2068.97 2107.62
# New York             1940.18 2060.06
# North Carolina       2184.70 2300.65
# North Dakota         1794.94 1725.25
# Ohio                 1918.32 2003.08
# Oklahoma             1823.08 1857.35
# Oregon               2336.27 2387.03
# Pennsylvania         1940.75 2030.52
# Puerto Rico          1813.61 1978.00
# Rhode Island         2091.75 2226.53
# South Carolina       2105.54 2225.90
# South Dakota         1907.55 1890.60
# Tennessee            2116.07 2225.69
# Texas                2501.67 2538.90
# Utah                 2481.68 2456.04
# Vermont              1677.03 1728.43
# Virginia             2129.50 2200.15
# Washington           2392.13 2399.00
# West Virginia        1887.67 1937.58
# Wisconsin            2023.69 2051.62
# Wyoming              2239.10 2152.41

# %% [markdown]
# # 5-Which state has the largest percentage of Hispanic residents?

# %%
df.groupby('State')['Hispanic'].sum().sort_values(ascending=False).head(10)
# Out:
# State
# California    299541.33
# Texas         199511.09
# Florida        90255.39
# Puerto Rico    88696.64
# New York       84770.23
# Illinois       48734.30
# Arizona        45041.38
# New Jersey     37671.40
# Colorado       25932.24
# New Mexico     22567.76
# Name: Hispanic, dtype: float64

# %% [markdown]
# # 6-How does the percentage of the Black population vary between states?

# %%
state_percentage_of_black=df.groupby('State')['Black'].sum().reset_index(name='count').sort_values(by='count',ascending=False).head(10)
state_percentage_of_black
# Out:
#              State    count
# 32        New York 76909.33
# 9          Florida 64240.10
# 10         Georgia 62956.07
# 44           Texas 61399.16
# 13        Illinois 53398.88
# 22        Michigan 49335.93
# 35            Ohio 47811.60
# 33  North Carolina 46767.34
# 4       California 46084.57
# 20        Maryland 42837.03

# %%
sns.barplot(state_percentage_of_black,x='State',y='count')
# state_percentage_of_black
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # what is the mean of total sale  for each state

# %%
df['Income']
# Out:
# 0       61838.00
# 1       32303.00
# 2       44922.00
# 3       54329.00
# 4       51965.00
#           ...
# 73996   21188.00
# 73997   25781.00
# 73998   17284.00
# 73999   22083.00
# 74000    7953.00
# Name: Income, Length: 74001, dtype: float64

# %%
df.groupby('State')['Income'].sum()
# Out:
# State
# Alabama                 51230503.95
# Alaska                  11709854.69
# Arizona                 82775454.17
# Arkansas                28813714.69
# California             540938390.05
# Colorado                80623814.17
# Connecticut             63127349.04
# Delaware                13460089.26
# District of Columbia    13453756.69
# Florida                215807273.23
# Georgia                100168895.73
# Hawaii                  25090298.03
# Idaho                   14309160.00
# Illinois               186059654.34
# Indiana                 73545213.65
# Iowa                    43752269.69
# Kansas                  41528661.21
# Kentucky                50625007.21
# Louisiana               51930733.69
# Maine                   17663451.95
# Maryland               110184117.69
# Massachusetts          107281227.56
# Michigan               144530717.88
# Minnesota               84015108.95
# Mississippi             25982711.52
# Missouri                69380927.52
# Montana                 12940719.69
# Nebraska                29752798.26
# Nevada                  38162014.08
# New Hampshire           20240503.69
# New Jersey             153540867.30
# New Mexico              23627549.56
# New York               315284625.74
# North Carolina         109860529.21
# North Dakota            11928563.00
# Ohio                   146718559.17
# Oklahoma                50340867.69
# Oregon                  45289349.08
# Pennsylvania           180792428.21
# Puerto Rico             22136260.54
# Rhode Island            14418967.26
# South Carolina          51294882.86
# South Dakota            11500800.00
# Tennessee               71107475.69
# Texas                  294268530.28
# Utah                    37306430.26
# Vermont                 10232568.56
# Virginia               138282948.29
# Washington              93915622.04
# West Virginia           20055562.00
# Wisconsin               76006741.73
# Wyoming                  7754504.56
# Name: Income, dtype: float64

# %%
df[['IncomePerCap','Poverty']]
plt.plot(df['IncomePerCap'],df['Poverty'],lw=0.8,marker='o',alpha=1)
plt.show()

# %%
corrlation=df.iloc[0:,3:-1]
heatmap_df=corrlation.corr()
# heatmap_df['Income'].
for i ,x in heatmap_df['Income'].items() :
    if x >=0.5 and i!='Income':
        print(i,x)
# Out:
# IncomeErr 0.6141189516733961
# IncomePerCap 0.8215056037751802
# Professional 0.7260524004253861

# %%
plt.figure(figsize=(10,5))
sns.heatmap(heatmap_df,linewidths=0.8)
plt.show()

# %%
ChildPoverty=df.groupby('County')['ChildPoverty'].sum().sort_values(ascending=False).reset_index(name='count').head(10)
ChildPoverty
# Out:
#         County    count
# 0  Los Angeles 56134.04
# 1         Cook 32952.53
# 2        Wayne 27570.46
# 3    Jefferson 22323.72
# 4        Kings 21409.80
# 5     Maricopa 21273.80
# 6       Harris 21030.96
# 7       Orange 16648.21
# 8       Dallas 15686.87
# 9        Clark 14891.81

# %%
sns.barplot(ChildPoverty,y='County',x='count')
plt.show()

# %% [markdown]
# # 11.Is there a relationship between the rate of employment in the public sector (Public Work) and the rate of unemployment (Unemployment) ?

# %%
sns.scatterplot(df,x='PublicWork',y='Unemployment')
plt.show()

# %%
df['PublicWork']
# Out:
# 0       18.30
# 1       16.90
# 2       23.60
# 3       21.20
# 4       27.60
#          ...
# 73996   31.30
# 73997   32.60
# 73998   32.30
# 73999   31.20
# 74000   19.60
# Name: PublicWork, Length: 74001, dtype: float64

# %%
df['Unemployment']
# Out:
# 0        5.40
# 1       13.30
# 2        6.20
# 3       10.80
# 4        4.20
#          ...
# 73996   21.30
# 73997   22.40
# 73998   23.30
# 73999   26.70
# 74000   20.10
# Name: Unemployment, Length: 74001, dtype: float64

# %%
group_PublicWork_Unemployment=df.groupby('State')[['Unemployment','PublicWork','PrivateWork','SelfEmployed']].sum().reset_index(names='country')
group_PublicWork_Unemployment
# Out:
#                  country  Unemployment  PublicWork  PrivateWork  SelfEmployed
# 0                Alabama      12611.07    19198.03     92446.35       6218.00
# 1                 Alaska       1547.53     4593.92     10882.38       1188.43
# 2                Arizona      14446.22    23438.54    119409.53       9499.67
# 3               Arkansas       5851.73    11714.92     52259.68       4483.13
# 4             California      82034.49   112671.87    622487.82      69073.10
# 5               Colorado       9009.27    17998.78     98230.08       8437.54
# 6            Connecticut       7813.17    10836.33     67087.35       5227.90
# 7               Delaware       1737.91     3161.49     17676.20        931.74
# 8   District of Columbia       2080.80     4623.30     12512.40        744.50
# 9                Florida      42463.44    53558.70    343378.44      26858.47
# 10               Georgia      20380.93    31215.22    154208.43      11130.11
# 11                Hawaii       2261.43     7611.68     25001.71       2419.32
# 12                 Idaho       2179.03     4923.42     22360.28       2422.53
# 13              Illinois      32162.73    40346.19    256510.08      14997.90
# 14               Indiana      13511.07    16500.23    127193.95       7160.30
# 15                  Iowa       4384.06    10741.34     65672.55       5896.57
# 16                Kansas       5015.72    12169.94     59413.83       5255.37
# 17              Kentucky      10223.70    17414.55     87441.73       6442.24
# 18             Louisiana      10383.50    17966.45     90090.18       6599.71
# 19                 Maine       2614.60     5171.05     27253.73       3324.14
# 20              Maryland      11419.87    30757.73    102922.30       6747.58
# 21         Massachusetts      11817.96    18279.15    120244.80       9084.64
# 22              Michigan      32030.69    31837.72    234370.67      14578.33
# 23             Minnesota       7916.97    16242.53    109128.05       8207.00
# 24           Mississippi       7564.80    12611.45     50089.33       3602.04
# 25              Missouri      11414.74    18174.91    112505.98       8344.87
# 26               Montana       1707.06     5269.84     18825.95       2806.07
# 27              Nebraska       2571.49     7560.06     41429.53       4085.20
# 28                Nevada       7447.26     8611.59     56306.38       3708.90
# 29         New Hampshire       1726.19     4011.06     23303.63       2142.90
# 30            New Jersey      18785.30    28505.70    162787.65       9434.17
# 31            New Mexico       4695.43    11583.32     34767.58       3438.23
# 32              New York      42894.54    78314.65    384150.12      28662.73
# 33        North Carolina      21731.30    32552.80    173377.71      13186.45
# 34          North Dakota        601.30     3551.10     14732.90       2132.40
# 35                  Ohio      28933.67    36685.78    243529.08      14562.94
# 36              Oklahoma       7281.13    17734.42     79843.48       6775.53
# 37                Oregon       7866.06    12199.59     64215.98       6834.90
# 38          Pennsylvania      27509.73    35071.77    269943.86      16310.64
# 39           Puerto Rico      17939.89    21506.37     64332.74       8496.70
# 40          Rhode Island       2157.81     3040.29     20134.70       1202.14
# 41        South Carolina      11222.40    17597.50     86643.15       5883.87
# 42          South Dakota       1103.20     3839.40     16028.80       2246.50
# 43             Tennessee      13713.12    21436.39    117637.35      10383.41
# 44                 Texas      38986.60    74287.81    414877.96      36431.72
# 45                  Utah       3477.71     9103.29     46838.10       2768.04
# 46               Vermont       1023.03     2689.42     13839.88       1823.63
# 47              Virginia      13247.32    38950.79    141868.31       9641.28
# 48            Washington      11878.17    24716.48    111725.68       9086.94
# 49         West Virginia       3961.30     9090.60     37131.40       2124.50
# 50             Wisconsin      10104.82    17440.99    115814.35       7384.21
# 51               Wyoming        686.83     2900.02      9382.58        879.33

# %%
group_PublicWork_Unemployment.sort_values(by='SelfEmployed',ascending=False)[['country','SelfEmployed']]
# sns.lineplot(group_PublicWork_Unemployment,y='Unemployment',x='SelfEmployed')
# plt.show()
# Out:
#                  country  SelfEmployed
# 4             California      69073.10
# 44                 Texas      36431.72
# 32              New York      28662.73
# 9                Florida      26858.47
# 38          Pennsylvania      16310.64
# 13              Illinois      14997.90
# 22              Michigan      14578.33
# 35                  Ohio      14562.94
# 33        North Carolina      13186.45
# 10               Georgia      11130.11
# 43             Tennessee      10383.41
# 47              Virginia       9641.28
# 2                Arizona       9499.67
# 30            New Jersey       9434.17
# 48            Washington       9086.94
# 21         Massachusetts       9084.64
# 39           Puerto Rico       8496.70
# 5               Colorado       8437.54
# 25              Missouri       8344.87
# 23             Minnesota       8207.00
# 50             Wisconsin       7384.21
# 14               Indiana       7160.30
# 37                Oregon       6834.90
# 36              Oklahoma       6775.53
# 20              Maryland       6747.58
# 18             Louisiana       6599.71
# 17              Kentucky       6442.24
# 0                Alabama       6218.00
# 15                  Iowa       5896.57
# 41        South Carolina       5883.87
# 16                Kansas       5255.37
# 6            Connecticut       5227.90
# 3               Arkansas       4483.13
# 27              Nebraska       4085.20
# 28                Nevada       3708.90
# 24           Mississippi       3602.04
# 31            New Mexico       3438.23
# 19                 Maine       3324.14
# 26               Montana       2806.07
# 45                  Utah       2768.04
# 12                 Idaho       2422.53
# 11                Hawaii       2419.32
# 42          South Dakota       2246.50
# 29         New Hampshire       2142.90
# 34          North Dakota       2132.40
# 49         West Virginia       2124.50
# 46               Vermont       1823.63
# 40          Rhode Island       1202.14
# 1                 Alaska       1188.43
# 7               Delaware        931.74
# 51               Wyoming        879.33
# 8   District of Columbia        744.50

# %%
fig,ax=plt.subplots(nrows=3,ncols=3,figsize=(20,10))
sns.lineplot(group_PublicWork_Unemployment,y='Unemployment',x='PublicWork',ax=ax[0,0],label='n')
sns.barplot(group_PublicWork_Unemployment.head(7),y='country',x='Unemployment',ax=ax[0,1])



ax[0,0].set_title('relationship between unemployment and publicwork')
ax[0,1].set_title('the most unemployment for each state')
# plt.title('relationship between unemployment and publicwork')
plt.show()
