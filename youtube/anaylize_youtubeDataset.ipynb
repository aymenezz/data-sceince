# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
# %matplotlib inline 
sns.set()

# %%
df_ca=pd.read_csv('./CAvideos.csv')

# %%
df_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40881 entries, 0 to 40880
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40881 non-null  object
#  1   trending_date           40881 non-null  object
#  2   title                   40881 non-null  object
#  3   channel_title           40881 non-null  object
#  4   category_id             40881 non-null  int64
#  5   publish_time            40881 non-null  object
#  6   tags                    40881 non-null  object
#  7   views                   40881 non-null  int64
#  8   likes                   40881 non-null  int64
#  9   dislikes                40881 non-null  int64
#  10  comment_count           40881 non-null  int64
#  11  thumbnail_link          40881 non-null  object
#  12  comments_disabled       40881 non-null  bool
#  13  ratings_disabled        40881 non-null  bool
# ...

# %%
df_ca.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
df_ca.tail()
# Out:
#           video_id trending_date  \
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 40876                       HOW2: How to Solve a Mystery   Annoying Orange
# 40877                   Eli Lik Lik Episode 13 Partie 01  Elhiwar Ettounsi
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...    Kingdom Hearts
# 40879                   Trump Advisor Grovels To Trudeau   The Young Turks
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班          我愛小明星大跟班
#
#        category_id              publish_time  \
# 40876           24  2018-06-13T18:00:07.000Z
# 40877           24  2018-06-13T19:01:18.000Z
# 40878           20  2018-06-11T17:30:53.000Z
# 40879           25  2018-06-13T04:00:05.000Z
# 40880           24  2018-06-13T16:00:03.000Z
#
# ...

# %%
df_ca.sample(10)
# Out:
#           video_id trending_date  \
# 28694  2mxMntQ12u8      18.14.04
# 23290  yqJPavtUKFs      18.12.03
# 21090  B82029-9A1M      18.01.03
# 2173   g979wc6o9Ks      17.24.11
# 22442  gD1KhjplXEQ      18.08.03
# 26747  S9KxqRUcnCU      18.30.03
# 5401   bvhBIsmzhwE      17.11.12
# 33545  YrlVffqU7sY      18.09.05
# 19692  gRP6MVU8b-s      18.22.02
# 13331  S_TB6_hTQ0o      18.21.01
#
#                                                    title  \
# 28694                          Future Raph's Only Regret
# 23290                                Dan has an accident
# 21090             White Parents Who Raise Black Children
# 2173   Chunkz ft Big Shaq & Team Alboe - GARDEN HOSE ...
# 22442  Khido Khundi - Official Trailer | Ranjit Bawa,...
# 26747               Boomerang Trick Shots | Dude Perfect
# 5401   17 Weird Ways To Sneak Makeup Into Class / Bac...
# 33545  When will Kilauea stop erupting? | Hawaii volc...
# 19692                          Daily Humor - Episode 175
# ...

# %%
df_ca.isna().sum()
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               1296
# dtype: int64

# %%
df_ca['description'].mode()
# Out:
# 0    Subscribers Link: http://bit.ly/2qb69dZ\n\nCon...
# Name: description, dtype: object

# %%
df_ca['description']=df_ca['description'].fillna('missing')

# %%
duplicate=df_ca['video_id'].duplicated().reset_index()

# %%
df_ca['video_id'].value_counts()
# Out:
# video_id
# 6ZfuNTqbHE8    8
# UceaB4D0jpo    8
# VYOjWnS4cMY    8
# l_lblj8Cq0o    8
# ZJDMWVZta3M    7
#               ..
# VH73_OD7GEk    1
# 2XsIu01UDoo    1
# zLlWRB_ou5I    1
# xcuVh80dPqo    1
# POTgw38-m58    1
# Name: count, Length: 24427, dtype: int64

# %%
df_ca.drop_duplicates(subset=['video_id'],inplace=True)

# %%
df_ca['video_id'].value_counts()
# Out:
# video_id
# n1WpP7iowLc    1
# CmO2143BzYA    1
# CI2zVegJBWA    1
# jzJd3NQzu6s    1
# E_1d1_T8KhA    1
#               ..
# GWMKelv5Bmw    1
# 6K6yLHau48k    1
# eNk12DW41js    1
# CmWFpmFLaVk    1
# POTgw38-m58    1
# Name: count, Length: 24427, dtype: int64

# %%
channel_group=df_ca.groupby('channel_title',as_index=False)['views'].count().sort_values(by='views',ascending=False).head(10)
channel_group
# Out:
#          channel_title  views
# 4203         VikatanTV    159
# 3268         SET India    154
# 2349             MSNBC    152
# 3111       RadaanMedia    149
# 3879   The Young Turks    147
# 117        ARY Digital    135
# 3257            SAB TV    118
# 631                CNN    118
# 3826  The Real Daytime    114
# 1132              ESPN    113

# %%
df_ca['views'].mean()
# Out:
# 486051.898309248

# %%
sns.barplot(channel_group,y='channel_title',x='views')
plt.show()

# %%
catergle=df_ca.select_dtypes(include='object').columns[0:]
numeric=df_ca.select_dtypes(include='number').columns[0:]

# %%
corrlation=pd.get_dummies(df_ca[catergle]).join(df_ca[numeric])
corrlation.to_csv('./dummies.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 corrlation=pd.get_dummies(df_ca[catergle]).join(df_ca[numeric])
#       2 corrlation.to_csv('./dummies.csv',index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\encoding.py:224, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     214         dummy = _get_dummies_1d(
#     215             col[1],
#     216             prefix=pre,
#    (...)
#     221             dtype=dtype,
#     222         )
#     223         with_dummies.append(dummy)
# --> 224     result = concat(with_dummies, axis=1)
#     225 else:
#     226     result = _get_dummies_1d(
#     227         data,
#     228         prefix,
#    (...)
#     233         dtype=dtype,
#     234     )
#
# ...
